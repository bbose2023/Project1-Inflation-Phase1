# %%
import import_ipynb as ipynb

# %%
# To import Kanha's function
from house_price import inflation_over_year
from house_price import regionwise_HPI
from house_price import heatmap
from house_price import correlation_cpi_mortgage
from house_price import HPI_inflation_vs_MR_CPI
from house_price import correlation_between_HPI_CPI

# %%
#To import Yashesh's function
from edu_inflation import plotInstateheatmap
from edu_inflation import plotinstateregionwise
from edu_inflation import plotoutstateregionwise
from edu_inflation import outstateincreseregionwise
from edu_inflation import plotavgchangeinvsout
from edu_inflation import plotavgfinalcomparision

# %%
#To import Anirudh's's function
from agriculture_climatechange_inflation import c02emissionpercentchange
from agriculture_climatechange_inflation import agriculturepercentchange
from agriculture_climatechange_inflation import correlationgraph1
from agriculture_climatechange_inflation import c02emissionvsagriculturevalue
from agriculture_climatechange_inflation import correlationregressiongraph
from globalfoodprices_inflation import foodpricesvsinflation
# Out:
# importing Jupyter notebook from agriculture_climatechange_inflation.ipynb
# Index(['Agriculture, forestry, and fishing, value added (% of GDP)',
#        'Arable land (hectares per person)',
#        'CO2 emissions (metric tons per capita)'],
#       dtype='object')
# <string>:4: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
# <string>:4: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
# ...

# %%
#To import Bony's function

from us_commodity_inflation import plotRIForMajorCategoriesInUS
from us_commodity_inflation import plotRIForSubCategoriesInUS
from us_commodity_inflation import plotCPIChangeLineGraph
from us_commodity_inflation import plotRIPerRegion
from us_commodity_inflation import plotRIForCategoriesPerRegion
from us_commodity_inflation import plotCPIChangeLineGraphByRegion
